# %%
import pandas as pd
import fbprophet
from fbprophet import Prophet
print(fbprophet.__version__)
from fbprophet.plot import plot_plotly
# Out:
# 0.5

# %%
df = pd.read_csv('Data/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\User\AppData\Local\conda\conda\envs\tfp3.6\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.203217    7.465358    8.906855
# 3266 2017-01-16  8.528203    7.784773    9.244588
# 3267 2017-01-17  8.315601    7.585013    8.998452
# 3268 2017-01-18  8.148207    7.368884    8.875105
# 3269 2017-01-19  8.160103    7.425698    8.852971

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_components_plotly
plot_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-f945db9b86d8> in <module>
# ----> 1 from fbprophet.plot import plot_components_plotly
#       2 plot_plotly(m, forecast)
#
# ImportError: cannot import name 'plot_components_plotly'

# %%
plot_components_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-371010a93432> in <module>
# ----> 1 plot_components_plotly(m, forecast)
#
# NameError: name 'plot_components_plotly' is not defined
